# %% [markdown]
# # Brain Tumor Segmentation

# %% [markdown]
# ## (Un)Healthy Brain Classification

# %%
import os
import cv2
import urllib
from PIL import Image
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import albumentations
import time
import argparse
from tqdm import tqdm
import warnings
import sklearn as sk
import itertools
import zlib

# Pytorch libraries and subsidiaries
import torch
import torch.nn as nn
import torch.optim as optim
import torch.cuda as cuda
import torchvision as tv
from torch.utils.data import TensorDataset, DataLoader, Dataset
from torchvision import transforms as T
from torchsummary import summary # allows for keras-like summaries of models in pytorch
from torchvision.utils import make_grid

# %% [markdown]
# ### Check CUDA Capability and Set Device

# %%
if cuda.is_available():
    device = torch.device('cuda:0')
    print('Running on ' + cuda.get_device_name(device))
else:
    device = torch.device('cpu')
    print('Running on the CPU')
# Out:
# Running on NVIDIA GeForce GTX 1070

# %%
# Download an example image
path = ('brain-tumor-dataset/Brain Tumor/Cancer (1).png')

input_image = Image.open(path)

display(input_image)
cv2.imread(path).shape
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=240x300 at 0x221FCCC7A60>
# (300, 240, 3)

# %% [markdown]
# ### Create Pandas Dataframe of Images

# %%
tumor_dir = 'brain-tumor-dataset/Brain Tumor'
healthy_dir = 'brain-tumor-dataset/Healthy'
dirlist = [tumor_dir, healthy_dir]
classes = [1, 0] # 1 = tumor, 0 = no tumor
filepaths = []
labels = []
for d,c in zip(dirlist, classes):
    flist = os.listdir(d)
    for f in flist:
        fpath = os.path.join (d,f)
        filepaths.append(fpath)
        labels.append(c)
print ('filepaths: ', len(filepaths), '   labels: ', len(labels))

Fseries = pd.Series(filepaths, name='file_paths')
Lseries = pd.Series(labels, name='labels')
df = pd.concat([Fseries,Lseries], axis=1, names=['file_paths', 'labels'])
df = pd.DataFrame(np.array(df).reshape(8117,2), columns=['file_paths', 'labels'])
print(df['labels'].value_counts())
# Out:
# filepaths:  8117    labels:  8117
# 1    5432
# 0    2685
# Name: labels, dtype: int64

# %% [markdown]
# ### Dataset Splitting

# %%
train_df, test_df = train_test_split(df, train_size=0.90, random_state=0)
test_df, valid_df = train_test_split(test_df, train_size=0.5, random_state=0)

print('Training Set:')
print(train_df.labels.value_counts())
print('Validation Set:')
print(valid_df.labels.value_counts())
print('Test Set:')
print(test_df.labels.value_counts())
# Out:
# Training Set:
# 1    4885
# 0    2420
# Name: labels, dtype: int64
# Validation Set:
# 1    278
# 0    128
# Name: labels, dtype: int64
# Test Set:
# 1    269
# 0    137
# Name: labels, dtype: int64

# %%
X_train = train_df.file_paths.values
y_train = train_df.labels.values
X_valid = valid_df.file_paths.values
y_valid = valid_df.labels.values
X_test = test_df.file_paths.values
y_test = test_df.labels.values

# %%
class BrainMRIDataset(Dataset):
    def __init__(self, X, y):
        self.X = X 
        self.y = y
    
    transform = T.Compose([
        T.Resize((224, 224)),
        T.ToTensor()])

    def __len__(self):
        return (len(self.X))
    
    def __getitem__(self, i):
        image = Image.open(self.X[i])
        image = image.convert('RGB')
        image = self.transform(image)
        image = np.transpose(image, (0, 2, 1))
        label = self.y[i]
        return torch.tensor(image, dtype=torch.float), torch.tensor(label, dtype=torch.long)

# %%
train_data = BrainMRIDataset(X_train, y_train)
valid_data = BrainMRIDataset(X_valid, y_valid)
test_data = BrainMRIDataset(X_test, y_test)

trainloader = DataLoader(train_data, batch_size=32, shuffle=True)
validloader = DataLoader(valid_data, batch_size=1, shuffle=False)
testloader = DataLoader(test_data, batch_size=1, shuffle=False)

# %% [markdown]
# ### ResNet Model Definition

# %%
def resnet_model(pretrained, requires_grad):
    resnet_model = tv.models.resnet152(progress=True, pretrained=pretrained)
    # freeze hidden layers
    if requires_grad == False:
        for param in resnet_model.parameters():
            param.requires_grad = False
    # train the hidden layers
    elif requires_grad == True:
        for param in resnet_model.parameters():
            param.requires_grad = True
    # make the classification layer learnable
    resnet_model.fc = nn.Linear(resnet_model.fc.in_features, 2)
    return resnet_model
    
resnet_model = resnet_model(pretrained=True, requires_grad=False).to(device) # Frozen hidden layers model 
# print(model)

# %%
# optimizer
optimizer = optim.SGD(resnet_model.parameters(), lr=1e-3, momentum=0.85, weight_decay=1e-4)
# loss function
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# %%
# validation function
def validate(model, valid_dataloader):
    print('Validating')
    model.eval()
    val_running_loss = 0.0
    val_running_correct = 0
    
    with torch.no_grad():
        for i, data in tqdm(enumerate(valid_dataloader), total=int(len(valid_data)/valid_dataloader.batch_size)):
            data, target = data[0].to(device), data[1].to(device)
            outputs = model(data)
            loss = criterion(outputs, target)
            
            val_running_loss += loss.item()
            _, preds = torch.max(outputs.data, 1)
            val_running_correct += (preds == target).sum().item()
        
        val_loss = val_running_loss/len(valid_dataloader.dataset)
        val_accuracy = 100. * val_running_correct/len(valid_dataloader.dataset)
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.2f}')
        
        return val_loss, val_accuracy

# %%
# training function
def fit(model, train_dataloader):
    print('Training')
    model.train()
    train_running_loss = 0.0
    train_running_correct = 0
    
    for i, data in tqdm(enumerate(train_dataloader), total=int(len(train_data)/train_dataloader.batch_size)):
        data, target = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, target)
        train_running_loss += loss.item()
        _, preds = torch.max(outputs.data, 1)
        train_running_correct += (preds == target).sum().item()
        loss.backward()
        optimizer.step()
        
    train_loss = train_running_loss / len(train_dataloader.dataset)
    train_accuracy = 100. * train_running_correct / len(train_dataloader.dataset)
    
    print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.2f}")
    
    return train_loss, train_accuracy

# %%
# %%capture
# %%script false --no-raise-error
warnings.filterwarnings('ignore')

print('CUDA Enabled: ' + str(next(resnet_model.parameters()).is_cuda))

train_loss , train_accuracy = [], []
val_loss , val_accuracy = [], []
start = time.time()

for epoch in range(25):
    print(f"Epoch {epoch + 1} of 25")
    train_epoch_loss, train_epoch_accuracy = fit(resnet_model, trainloader)
    val_epoch_loss, val_epoch_accuracy = validate(resnet_model, validloader)
    train_loss.append(train_epoch_loss)
    train_accuracy.append(train_epoch_accuracy)
    val_loss.append(val_epoch_loss)
    val_accuracy.append(val_epoch_accuracy)

end = time.time()
print(f"{(end-start) / 60:.3f} minutes")

y = val_loss
x = [ i for i in range(1, 26) ]
fig = plt.figure(figsize=(10,7.5))
ax = fig.add_subplot(111)
ax.plot(x, y)
_ = plt.xlabel("Epochs")
_ = plt.ylabel("Validation Loss")
# Out:
#   0%|          | 0/228 [00:00<?, ?it/s]
# CUDA Enabled: True
# Epoch 1 of 25
# Training
# 229it [01:27,  2.61it/s]
#   1%|          | 3/406 [00:00<00:14, 28.30it/s]
# Train Loss: 0.0115, Train Acc: 83.61
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 29.74it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.2473, Val Acc: 91.13
# Epoch 2 of 25
# Training
# 229it [01:24,  2.72it/s]
#   1%|          | 3/406 [00:00<00:14, 27.28it/s]
# Train Loss: 0.0081, Train Acc: 90.42
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.65it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.2170, Val Acc: 92.12
# Epoch 3 of 25
# Training
# 229it [01:26,  2.66it/s]
#   1%|          | 3/406 [00:00<00:14, 28.30it/s]
# Train Loss: 0.0071, Train Acc: 91.42
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 29.95it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1957, Val Acc: 92.86
# Epoch 4 of 25
# Training
# 229it [01:27,  2.62it/s]
#   1%|          | 3/406 [00:00<00:14, 28.17it/s]
# Train Loss: 0.0068, Train Acc: 92.06
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.94it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1800, Val Acc: 93.60
# Epoch 5 of 25
# Training
# 229it [01:25,  2.67it/s]
#   1%|          | 3/406 [00:00<00:16, 24.90it/s]
# Train Loss: 0.0064, Train Acc: 92.65
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 29.68it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1712, Val Acc: 93.60
# Epoch 6 of 25
# Training
# 229it [01:25,  2.68it/s]
#   1%|          | 3/406 [00:00<00:13, 28.85it/s]
# Train Loss: 0.0059, Train Acc: 93.18
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 29.53it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1781, Val Acc: 93.10
# Epoch 7 of 25
# Training
# 229it [01:26,  2.65it/s]
#   1%|          | 3/406 [00:00<00:14, 28.30it/s]
# Train Loss: 0.0057, Train Acc: 93.43
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.83it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1630, Val Acc: 93.35
# Epoch 8 of 25
# Training
# 229it [01:27,  2.62it/s]
#   1%|          | 3/406 [00:00<00:14, 28.44it/s]
# Train Loss: 0.0057, Train Acc: 93.55
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 29.79it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1509, Val Acc: 94.83
# Epoch 9 of 25
# Training
# 229it [01:24,  2.71it/s]
#   1%|          | 3/406 [00:00<00:14, 28.04it/s]
# Train Loss: 0.0054, Train Acc: 93.73
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 31.02it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1469, Val Acc: 95.57
# Epoch 10 of 25
# Training
# 229it [01:24,  2.72it/s]
#   1%|          | 3/406 [00:00<00:13, 29.27it/s]
# Train Loss: 0.0056, Train Acc: 93.20
# Validating
# 100%|██████████| 406/406 [00:12<00:00, 31.44it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1514, Val Acc: 94.09
# Epoch 11 of 25
# Training
# 229it [01:23,  2.73it/s]
#   1%|          | 4/406 [00:00<00:12, 31.50it/s]
# Train Loss: 0.0051, Train Acc: 94.10
# Validating
# 100%|██████████| 406/406 [00:12<00:00, 31.24it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1699, Val Acc: 92.61
# Epoch 12 of 25
# Training
# 229it [01:24,  2.72it/s]
#   1%|          | 4/406 [00:00<00:12, 33.47it/s]
# Train Loss: 0.0053, Train Acc: 93.87
# Validating
# 100%|██████████| 406/406 [00:12<00:00, 31.29it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1541, Val Acc: 93.10
# Epoch 13 of 25
# Training
# 229it [01:23,  2.73it/s]
#   1%|          | 3/406 [00:00<00:14, 27.65it/s]
# Train Loss: 0.0051, Train Acc: 94.20
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 31.13it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1472, Val Acc: 93.35
# Epoch 14 of 25
# Training
# 229it [01:24,  2.72it/s]
#   1%|▏         | 6/406 [00:00<00:13, 29.11it/s]
# Train Loss: 0.0049, Train Acc: 94.43
# Validating
# 100%|██████████| 406/406 [00:12<00:00, 31.24it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1408, Val Acc: 93.60
# Epoch 15 of 25
# Training
# 229it [01:24,  2.70it/s]
#   1%|▏         | 6/406 [00:00<00:14, 28.48it/s]
# Train Loss: 0.0049, Train Acc: 94.11
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.76it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1387, Val Acc: 94.33
# Epoch 16 of 25
# Training
# 229it [01:25,  2.67it/s]
#   1%|          | 3/406 [00:00<00:16, 25.10it/s]
# Train Loss: 0.0048, Train Acc: 94.29
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.17it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1432, Val Acc: 94.33
# Epoch 17 of 25
# Training
# 229it [01:27,  2.61it/s]
#   1%|          | 4/406 [00:00<00:12, 32.39it/s]
# Train Loss: 0.0048, Train Acc: 94.69
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 29.44it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1285, Val Acc: 95.07
# Epoch 18 of 25
# Training
# 229it [01:25,  2.68it/s]
#   1%|          | 3/406 [00:00<00:15, 25.86it/s]
# Train Loss: 0.0046, Train Acc: 94.85
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.38it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1260, Val Acc: 95.57
# Epoch 19 of 25
# Training
# 229it [01:25,  2.67it/s]
#   1%|          | 3/406 [00:00<00:15, 26.79it/s]
# Train Loss: 0.0047, Train Acc: 94.58
# Validating
# 100%|██████████| 406/406 [00:14<00:00, 28.11it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1248, Val Acc: 94.83
# Epoch 20 of 25
# Training
# 229it [01:24,  2.70it/s]
#   1%|          | 4/406 [00:00<00:12, 31.37it/s]
# Train Loss: 0.0047, Train Acc: 94.54
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.43it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1469, Val Acc: 95.07
# Epoch 21 of 25
# Training
# 229it [01:23,  2.75it/s]
#   1%|          | 3/406 [00:00<00:13, 29.27it/s]
# Train Loss: 0.0047, Train Acc: 94.28
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.07it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1323, Val Acc: 95.07
# Epoch 22 of 25
# Training
# 229it [01:28,  2.59it/s]
#   1%|          | 3/406 [00:00<00:15, 25.64it/s]
# Train Loss: 0.0044, Train Acc: 95.02
# Validating
# 100%|██████████| 406/406 [00:14<00:00, 28.20it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1271, Val Acc: 95.32
# Epoch 23 of 25
# Training
# 229it [01:31,  2.51it/s]
#   1%|          | 3/406 [00:00<00:15, 26.55it/s]
# Train Loss: 0.0045, Train Acc: 94.74
# Validating
# 100%|██████████| 406/406 [00:14<00:00, 28.10it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1258, Val Acc: 95.07
# Epoch 24 of 25
# Training
# 229it [01:26,  2.66it/s]
#   1%|          | 3/406 [00:00<00:14, 27.78it/s]
# Train Loss: 0.0043, Train Acc: 94.99
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.72it/s]
#   0%|          | 0/228 [00:00<?, ?it/s]
# Val Loss: 0.1302, Val Acc: 95.07
# Epoch 25 of 25
# Training
# 229it [01:22,  2.76it/s]
#   1%|          | 3/406 [00:00<00:14, 27.03it/s]
# Train Loss: 0.0042, Train Acc: 95.22
# Validating
# 100%|██████████| 406/406 [00:13<00:00, 30.74it/s]
# Val Loss: 0.1276, Val Acc: 95.32
# 41.301 minutes

# %%
# %%capture --no-stderr
# %%script false --no-raise-error
PATH = './resnet_brain_recent.pth'
torch.save(resnet_model, PATH)

# %%
# if torch.cuda.is_available():
#     resnet_model = torch.load('./resnet_brain_v2.pth', map_location='cuda:0')
# else:
#     resnet_model = torch.load('./resnet_brain_v2.pth', map_location=torch.device('cpu'))

# %%
# Testing
warnings.filterwarnings('ignore')
correct = 0
total = 0
X_wrong = []
if torch.cuda.is_available():
    y_pred = torch.Tensor([]).cuda()
else:
    y_pred = torch.Tensor([])

resnet_model.eval()

with torch.no_grad():
    for data in testloader:
        images, labels = data
        if torch.cuda.is_available():
            images, labels = images.cuda(), labels.cuda()
        outputs = resnet_model(images) # feed images into resnet and get predictions
        y_pred = torch.cat((y_pred, outputs), dim=0)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        if(predicted != labels):
            X_wrong.append((images.cpu(), labels.cpu()))

y_pred = np.uint8(np.argmax(y_pred.cpu(), axis=1))
y_test = np.uint8(y_test)

# %%
print(sk.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       137
#            1       0.96      0.96      0.96       269
#
#     accuracy                           0.95       406
#    macro avg       0.94      0.94      0.94       406
# weighted avg       0.95      0.95      0.95       406

# %%
conf_matrix = sk.metrics.confusion_matrix(y_test, y_pred)

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_confusion_matrix(conf_matrix, ['tumor', 'healthy'])
# Out:
# Confusion matrix, without normalization
# [[126  11]
#  [ 10 259]]

# %%
fig = plt.figure()
plt.axis('off')
wrong_index = 11
print('Total Misclassified: ' + str(len(X_wrong)))
if X_wrong[wrong_index][1].item() == 1:
    print('Predicted Label: Healthy\nTrue Label: Tumor\nFalse Negative')
else:
    print('Predicted Label: Tumor\nTrue Label: Healthy\nFalse Positive')
    
plt.imshow(X_wrong[wrong_index][0].permute(3, 2, 0, 1).squeeze())
# Out:
# Total Misclassified: 21
# Predicted Label: Tumor
# True Label: Healthy
# False Positive
